# %%
import os
import sys

sys.path.append('../python')
sys.path.append('../data')

# %%
import pandas as pd

bj_table = pd.read_csv('../data/beijing_table.csv')
ld_table = pd.read_csv('../data/london_table.csv')

# %%
bj_table.head()
# Out:
#    Unnamed: 0    station_id             utc_time  PM2.5   PM10    NO2   CO  \
# 0           0  aotizhongxin  2017-01-01 14:00:00  453.0  467.0  156.0  7.2
# 1           1  aotizhongxin  2017-01-01 15:00:00  417.0  443.0  143.0  6.8
# 2           2  aotizhongxin  2017-01-01 16:00:00  395.0  467.0  141.0  6.9
# 3           3  aotizhongxin  2017-01-01 17:00:00  420.0  484.0  139.0  7.4
# 4           4  aotizhongxin  2017-01-01 18:00:00  453.0  520.0  157.0  7.6
#
#     O3  SO2       stationName  longitude  latitude  temperature  pressure  \
# 0  3.0  9.0  beijing_grid_304      116.4      40.0        -2.47   1018.38
# 1  2.0  8.0  beijing_grid_304      116.4      40.0        -2.27   1018.62
# 2  3.0  8.0  beijing_grid_304      116.4      40.0        -2.01   1018.78
# 3  3.0  9.0  beijing_grid_304      116.4      40.0        -1.75   1018.95
# 4  4.0  9.0  beijing_grid_304      116.4      40.0        -1.49   1019.12
#
#    humidity  wind_direction  wind_speed/kph
# ...

# %%
import utils
X, y = utils.fillNA(list(bj_table['utc_time'].values), list(bj_table['PM2.5'].values), 'random')

# %%
from rule_base_model import LastYearModel
lyModel = LastYearModel()
lyModel.train(X=X, y=y)

# %%
lyModel.predict('2018-06-12 00:00:00')
# Out:
# 34.0

# %%
bj_station_list = list(set(bj_table['station_id'].values))

# %%
bj_table[bj_table['station_id'] == 'aotizhongxin']
# Out:
#       Unnamed: 0    station_id             utc_time  PM2.5   PM10    NO2  \
# 0              0  aotizhongxin  2017-01-01 14:00:00  453.0  467.0  156.0
# 1              1  aotizhongxin  2017-01-01 15:00:00  417.0  443.0  143.0
# 2              2  aotizhongxin  2017-01-01 16:00:00  395.0  467.0  141.0
# 3              3  aotizhongxin  2017-01-01 17:00:00  420.0  484.0  139.0
# 4              4  aotizhongxin  2017-01-01 18:00:00  453.0  520.0  157.0
# 5             14  aotizhongxin  2017-01-02 04:00:00   58.0  247.0   76.0
# 6             16  aotizhongxin  2017-01-02 06:00:00  109.0  211.0   86.0
# 7             42  aotizhongxin  2017-01-03 08:00:00  296.0  334.0  190.0
# 8             45  aotizhongxin  2017-01-03 11:00:00  397.0  420.0  199.0
# 9             46  aotizhongxin  2017-01-03 12:00:00  437.0  448.0  199.0
# 10            47  aotizhongxin  2017-01-03 13:00:00  464.0  486.0  195.0
# 11            49  aotizhongxin  2017-01-03 15:00:00  447.0  476.0  196.0
# ...

# %%
import datetime

now = datetime.datetime.now()
start_time = datetime.datetime(2017,1,1,0,0,0)
start_time = start_time + datetime.timedelta(hours=25)

start_time.isoformat(' ')
# Out:
# '2017-01-02 01:00:00'

# %%
-1 % 4
# Out:
# 3
